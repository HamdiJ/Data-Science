# %% [markdown]
# # Régression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x = np.arange(7,58,10)
x
# Out:
# array([ 7, 17, 27, 37, 47, 57])

# %%
y = np.array([7, 18, 16, 24, 22, 30])

# %%
x = x.reshape((-1, 1))

# %%
x
# Out:
# array([[ 7],
#        [17],
#        [27],
#        [37],
#        [47],
#        [57]])

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)
plt.show()

# %%
model = LinearRegression()

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
Coef_dét = model.score(x, y)
print('Coefficient de détermination:', Coef_dét)
# Out:
# Coefficient de détermination: 0.8466898954703833

# %%
print('Ordonnée à l origine:', model.intercept_)
print('pente:', model.coef_)
# Out:
# Ordonnée à l origine: 7.157142857142855
# pente: [0.38571429]

# %%
y_pred = model.intercept_ + model.coef_ * x
print('prédictions:', y_pred, sep='\n')
# Out:
# prédictions:
# [[ 9.85714286]
#  [13.71428571]
#  [17.57142857]
#  [21.42857143]
#  [25.28571429]
#  [29.14285714]]

# %%
y_pred = model.predict(x)
print('prédictions:', y_pred, sep='\n')
# Out:
# prédictions:
# [ 9.85714286 13.71428571 17.57142857 21.42857143 25.28571429 29.14285714]

# %%
plt.scatter(x, y)
plt.plot(x, y_pred)
plt.show()

# %% [markdown]
# Supposons que vous soyez le chef de direction d’une franchise de camions ambulants (Food Trucks). Vous envisagez différentes villes pour ouvrir un nouveau point de vente. La chaîne a déjà des camions dans différentes villes et vous avez des données pour les bénéfices et les populations des villes.
# Vous souhaitez utiliser ces données pour vous aider à choisir la ville pour y ouvrir un nouveau point de vente.
# Les données sont en CSV :
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# ### Etape 1: Chargement des diverses librairies utiles pour ce notebook

# %%
# %matplotlib inline  
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Etape 2 : Chargement du jeu de données
#
# La fonction read_csv(), renvoie un DataFrame. Il s’agit d’un tableau de deux dimensions contenant, respectivement, la taille de population et les profits effectués. Pour pouvoir utiliser les librairies de régression de Python, il faudra séparer les deux colonnes dans deux variables Python.

# %%
df = pd.read_csv("datasets/univariate_linear_regression_dataset.csv")
X =  df.iloc[:,0] #selection de la première colonne de notre dataset (indice 0)
Y =  df.iloc[:,1] #selection de la première colonne de notre dataset (indice 1)
X=np.array(X)
X =X.reshape(-1, 1)

# %% [markdown]
# Etape 3 :
# Visualisation du jeu de données

# %%
axes = plt.axes()
axes.grid()
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# Etape 4 :
# Entrainement d'un modèle de régression linéaire

# %%
model = LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Etape 5 :
# Dessiner la fonction de prédiction

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, Y)
plt.plot(X, y_pred)
plt.show()

# %% [markdown]
# ### quelles est le Coefficient de détermination:

# %%
Coef_dét = model.score(X, Y)
print('Coefficient de détermination:', Coef_dét)
# Out:
# Coefficient de détermination: 0.7606583419339847

# %% [markdown]
# ### pour la valeur x = 22.5 y??

# %%
t=np.array([22.5])
t =t.reshape(-1, 1)
model.predict(t)
# Out:
# array([23.09330921])

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("datasets/Multivariate_Linear_Regression_dataset.xlsx")

# %%
df.head()
# Out:
#    taille_en_pieds_carre  nb_chambres    prix
# 0                   2104            3  399900
# 1                   1600            3  329900
# 2                   2400            3  369000
# 3                   1416            2  232000
# 4                   3000            4  539900

# %%
#Récupérer le prix : les valeurs observées pour la variable Cible
Y = df["prix"]
#Récupérer les variables prédictives : La superficie en pieds² et le nb chambre
X = df[['taille_en_pieds_carre','nb_chambres']]

# %%
import matplotlib.pyplot as plt
 
fig = plt.figure()
ax = fig.add_subplot(1,2,1, projection='3d')
ax.scatter(df["taille_en_pieds_carre"], df["nb_chambres"], df["prix"], c='r', marker='^')
 
ax.set_xlabel('surface en pieds_carre')
ax.set_ylabel('nb_chambres')
ax.set_zlabel('prix en $')
 
plt.show()

# %%
scale = StandardScaler()
X
# Out:
#     taille_en_pieds_carre  nb_chambres
# 0                    2104            3
# 1                    1600            3
# 2                    2400            3
# 3                    1416            2
# 4                    3000            4
# 5                    1985            4
# 6                    1534            3
# 7                    1427            3
# 8                    1380            3
# 9                    1494            3
# 10                   1940            4
# 11                   2000            3
# 12                   1890            3
# 13                   4478            5
# 14                   1268            3
# 15                   2300            4
# 16                   1320            2
# 17                   1236            3
# 18                   2609            4
# 19                   3031            4
# 20                   1767            3
# 21                   1888            2
# 22                   1604            3
# ...

# %%
X_scaled = scale.fit_transform(X[['taille_en_pieds_carre', 'nb_chambres']])

#print X_scaled

# %%
max(X_scaled[:,0])
# Out:
# 3.15099325527155

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.score(X, Y)
# Out:
# 0.7329450180289141

# %%
print('Ordonnée à l origine:', model.intercept_)
print('pente:', model.coef_)
# Out:
# Ordonnée à l origine: 89597.90954279748
# pente: [  139.21067402 -8738.01911233]

# %% [markdown]
# # TP régression polynomiale:

# %% [markdown]
# Un site e-commerce souhaite savoir si le temps de chargement des pages web de son site impacte le montant du panier moyen de l’internaute.
# On souhaite trouver une fonction de prédiction qui modélisera cette corrélation.

# %% [markdown]
# Etape 1 :
# Chargements des données
# montantAchat.csv
# tempsChargementPages.csv

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tempsChargementPages = pd.read_csv("datasets/tempsChargementPages.csv")

montantAchat=pd.read_csv("datasets/montantAchat.csv")

# %%
tempsChargementPages.head
# Out:
# <bound method NDFrame.head of        0  2.5832421525945293
# 0      1            2.943733
# 1      2            0.863804
# 2      3            4.640271
# 3      4            1.206564
# 4      5            2.158253
# ..   ...                 ...
# 994  995            3.081932
# 995  996            3.568726
# 996  997            2.765517
# 997  998            3.035110
# 998  999            3.196785
#
# [999 rows x 2 columns]>

# %%
tempsChargementPages =  tempsChargementPages.iloc[:,1] #selection de la première colonne de notre dataset (indice 0)
montantAchat=  montantAchat.iloc[:,1] #selection de la première colonne de notre dataset (indice 1)

# %%
axes = plt.axes()
axes.grid()
plt.xlabel('temps de chargement en secondes')
plt.ylabel('montant des achats euros')
plt.scatter(tempsChargementPages, montantAchat)
plt.show()

# %%
x = np.array(tempsChargementPages)

# %%
y = np.array(montantAchat)

# %% [markdown]
# Visualisation des données

# %%
axes = plt.axes()
axes.grid()
plt.xlabel('temps de chargement en secondes')
plt.ylabel('montant des achats euros')
plt.scatter(tempsChargementPages, montantAchat)
plt.show()

# %% [markdown]
# Retrouver une fonction polynomiale
#
# Plus on rajoute un degré au polynôme, plus ce dernier devient sensible aux données et s’y adapte mieux.
# trouvons un modèle avec un polynôme de 4 degrés.

# %%
x = np.array(tempsChargementPages)
y = np.array(montantAchat)

# %%
n=4
Coff=np.polyfit(x, y, n) # ax
fp = np.poly1d(Coff)

axes = plt.axes()
axes.grid()
xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, fp(xp), c='r')
plt.show()

# %%
np.linspace(0, 7, 100)
# Out:
# array([0.        , 0.07070707, 0.14141414, 0.21212121, 0.28282828,
#        0.35353535, 0.42424242, 0.49494949, 0.56565657, 0.63636364,
#        0.70707071, 0.77777778, 0.84848485, 0.91919192, 0.98989899,
#        1.06060606, 1.13131313, 1.2020202 , 1.27272727, 1.34343434,
#        1.41414141, 1.48484848, 1.55555556, 1.62626263, 1.6969697 ,
#        1.76767677, 1.83838384, 1.90909091, 1.97979798, 2.05050505,
#        2.12121212, 2.19191919, 2.26262626, 2.33333333, 2.4040404 ,
#        2.47474747, 2.54545455, 2.61616162, 2.68686869, 2.75757576,
#        2.82828283, 2.8989899 , 2.96969697, 3.04040404, 3.11111111,
#        3.18181818, 3.25252525, 3.32323232, 3.39393939, 3.46464646,
#        3.53535354, 3.60606061, 3.67676768, 3.74747475, 3.81818182,
#        3.88888889, 3.95959596, 4.03030303, 4.1010101 , 4.17171717,
#        4.24242424, 4.31313131, 4.38383838, 4.45454545, 4.52525253,
#        4.5959596 , 4.66666667, 4.73737374, 4.80808081, 4.87878788,
# ...
